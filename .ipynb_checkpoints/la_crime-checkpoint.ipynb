# %%
#Import dependencies
import pandas as pd
import sqlite3
import sys

# %%
#Assign database file to a variable
db_file = "Data/crimedata.db"

#Connect to database file
conn = sqlite3.connect(db_file)

# %%
#Query the la crime data table and put into a pandas dataframe
crime_df = pd.read_sql_query("select * from la_crime_1718;", conn)
crime_df.head()
# Out:
#     DRNumber DateReported DateOccurred TimeOccurred AreaID    AreaName  \
# 0  170209449    4/22/2017    4/21/2017         1930      2     Rampart
# 1  170206243    2/14/2017    2/11/2017         1700      2     Rampart
# 2  170311599    4/25/2017    4/25/2017         0745      3   Southwest
# 3  170408264     4/7/2017     4/7/2017         0001      4  Hollenbeck
# 4  170508584    4/10/2017     4/8/2017         0730      5      Harbor
#
#   ReportingDistrict CrimeCode CrimeCodeDescription MOCodes  \
# 0               201       510     VEHICLE - STOLEN
# 1               275       510     VEHICLE - STOLEN
# 2               325       510     VEHICLE - STOLEN
# 3               421       510     VEHICLE - STOLEN
# 4               566       510     VEHICLE - STOLEN
#
#            ...          WeaponDescription StatusCode StatusDescription  \
# 0          ...                                    IC       Invest Cont
# 1          ...                                    IC       Invest Cont
# ...

# %%
#Query the la weather history data table and put into a pandas dataframe
weather_df = pd.read_sql_query("select * from LA_weather_history_2016_to_2018;", conn)
weather_df.head()
# Out:
#      dt_iso hour    temp temp_min temp_max pressure humidity wind_speed  \
# 0  1/1/2016   01  288.14   281.15   292.15     1018       22          5
# 1  1/1/2016   03  284.27   275.15   289.15     1018       21          1
# 2  1/1/2016   05  283.38   274.15   287.15     1019       34          2
# 3  1/1/2016   06     282   272.59   286.15     1019       32          1
# 4  1/1/2016   07  280.74   270.93   285.15     1019       32          1
#
#   wind_deg rain_1h rain_3h clouds_all weather_id weather_description  \
# 0      260                          1        800           clear sky
# 1      310                          1        800           clear sky
# 2       20                          1        800           clear sky
# 3       16                          1        800           clear sky
# 4       18                          1        721                haze
#
#   weather_main
# 0        Clear
# 1        Clear
# 2        Clear
# 3        Clear
# 4         Haze

# %%
#Merge the weather history with the crime data

#First, strip the first two digits of the time occured column so that we can match it up with the weather

crime_df['hour'] = crime_df['TimeOccurred'].str.slice(0,2)
crime_df.head()
# Out:
#     DRNumber DateReported DateOccurred TimeOccurred AreaID    AreaName  \
# 0  170209449    4/22/2017    4/21/2017         1930      2     Rampart
# 1  170206243    2/14/2017    2/11/2017         1700      2     Rampart
# 2  170311599    4/25/2017    4/25/2017         0745      3   Southwest
# 3  170408264     4/7/2017     4/7/2017         0001      4  Hollenbeck
# 4  170508584    4/10/2017     4/8/2017         0730      5      Harbor
#
#   ReportingDistrict CrimeCode CrimeCodeDescription MOCodes ...  StatusCode  \
# 0               201       510     VEHICLE - STOLEN         ...          IC
# 1               275       510     VEHICLE - STOLEN         ...          IC
# 2               325       510     VEHICLE - STOLEN         ...          IC
# 3               421       510     VEHICLE - STOLEN         ...          IC
# 4               566       510     VEHICLE - STOLEN         ...          IC
#
#   StatusDescription CrimeCode1 CrimeCode2 CrimeCode3 CrimeCode4     Address  \
# ...

# %%
new_df = pd.merge(crime_df, weather_df, left_on=['DateOccurred', 'hour'], right_on=['dt_iso', 'hour'])
new_df.head()
# Out:
#     DRNumber DateReported DateOccurred TimeOccurred AreaID   AreaName  \
# 0  170209449    4/22/2017    4/21/2017         1930      2    Rampart
# 1  170112214    4/21/2017    4/21/2017         1915      1    Central
# 2  170209474    4/22/2017    4/21/2017         1930      2    Rampart
# 3  170209491    4/23/2017    4/21/2017         1900      2    Rampart
# 4  170311385    4/21/2017    4/21/2017         1905      3  Southwest
#
#   ReportingDistrict CrimeCode  \
# 0               201       510
# 1               153       440
# 2               237       330
# 3               241       420
# 4               319       480
#
#                               CrimeCodeDescription              MOCodes  \
# 0                                 VEHICLE - STOLEN
# 1               THEFT PLAIN - PETTY ($950 & UNDER)                  344
# 2                            BURGLARY FROM VEHICLE            0344 1606
# 3  THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...

# %%
#Drop columns from the dataframe that will not be needed in our ML models

model_df = new_df.drop(['DRNumber', 'DateReported', 'DateOccurred', 'AreaName', 'CrimeCodeDescription', 'MOCodes',
                       'PremiseDescription', 'weather_description', 'weather_main', 'rain_1h', 'rain_3h'],
                     axis=1)
model_df.head()
# Out:
#   TimeOccurred AreaID ReportingDistrict CrimeCode VictimAge VictimSex  \
# 0         1930      2               201       510        16
# 1         1915      1               153       440        48         F
# 2         1930      2               237       330        29         M
# 3         1900      2               241       420        16
# 4         1905      3               319       480        21         M
#
#   VictimDescent PremiseCode WeaponUsedCode WeaponDescription    ...      \
# 0                       101                                     ...
# 1             W         502                                     ...
# 2             H         101                                     ...
# 3                       101                                     ...
# 4             W         108                                     ...
#
#       dt_iso    temp temp_min temp_max pressure humidity wind_speed wind_deg  \
# ...

# %%
model_df = model_df.drop(['WeaponDescription', 'VictimSex', 'VictimDescent', 'StatusCode', 'StatusDescription',
                         'Address', 'CrossStreet', 'CrimeCode1', 'CrimeCode2', 'CrimeCode3', 'CrimeCode4','dt_iso'], axis=1)
model_df.head()
# Out:
#   TimeOccurred AreaID ReportingDistrict CrimeCode VictimAge PremiseCode  \
# 0         1930      2               201       510        16         101
# 1         1915      1               153       440        48         502
# 2         1930      2               237       330        29         101
# 3         1900      2               241       420        16         101
# 4         1905      3               319       480        21         108
#
#   WeaponUsedCode              Location hour    temp temp_min temp_max  \
# 0                 (34.0886, -118.2979)   19  300.09   295.15   304.15
# 1                  (34.0467, -118.252)   19  300.09   295.15   304.15
# 2                 (34.0646, -118.2656)   19  300.09   295.15   304.15
# 3                 (34.0671, -118.2806)   19  300.09   295.15   304.15
# 4                 (34.0288, -118.2756)   19  300.09   295.15   304.15
#
#   pressure humidity wind_speed wind_deg clouds_all weather_id
# ...

# %%
model_small_df = model_df.loc[model_df['CrimeCode'].isin(['420', '210', '230', '626', '740',
 '310', '510', '440', '330', '624'])]
model_small_df.head()
# Out:
#   TimeOccurred AreaID ReportingDistrict CrimeCode VictimAge PremiseCode  \
# 0         1930      2               201       510        16         101
# 1         1915      1               153       440        48         502
# 2         1930      2               237       330        29         101
# 3         1900      2               241       420        16         101
# 7         1930      6               642       420        16         101
#
#   WeaponUsedCode              Location hour    temp temp_min temp_max  \
# 0                 (34.0886, -118.2979)   19  300.09   295.15   304.15
# 1                  (34.0467, -118.252)   19  300.09   295.15   304.15
# 2                 (34.0646, -118.2656)   19  300.09   295.15   304.15
# 3                 (34.0671, -118.2806)   19  300.09   295.15   304.15
# 7                 (34.0981, -118.3577)   19  300.09   295.15   304.15
#
#   pressure humidity wind_speed wind_deg clouds_all weather_id
# ...

# %%
#COnvert the datatype of each column to numeric for machine learning
model_small_df['TimeOccurred'] = model_small_df['TimeOccurred'].apply(pd.to_numeric, errors='coerce')
model_small_df['AreaID'] = model_small_df['AreaID'].apply(pd.to_numeric, errors='coerce')
model_small_df['CrimeCode'] = model_small_df['CrimeCode'].apply(pd.to_numeric, errors='coerce')
model_small_df['ReportingDistrict'] = model_small_df['ReportingDistrict'].apply(pd.to_numeric, errors='coerce')
model_small_df['VictimAge'] = model_small_df['VictimAge'].apply(pd.to_numeric, errors='coerce')
model_small_df['PremiseCode'] = model_small_df['PremiseCode'].apply(pd.to_numeric, errors='coerce')
model_small_df['WeaponUsedCode'] = model_small_df['WeaponUsedCode'].apply(pd.to_numeric, errors='coerce')
model_small_df['Location'] = model_small_df['Location'].apply(pd.to_numeric, errors='coerce')
model_small_df['hour'] = model_small_df['hour'].apply(pd.to_numeric, errors='coerce')
model_small_df['temp'] = model_small_df['temp'].apply(pd.to_numeric, errors='coerce')
model_small_df['temp_min'] = model_small_df['temp_min'].apply(pd.to_numeric, errors='coerce')
model_small_df['temp_max'] = model_small_df['temp_max'].apply(pd.to_numeric, errors='coerce')
model_small_df['pressure'] = model_small_df['pressure'].apply(pd.to_numeric, errors='coerce')
model_small_df['humidity'] = model_small_df['humidity'].apply(pd.to_numeric, errors='coerce')
model_small_df['wind_speed'] = model_small_df['wind_speed'].apply(pd.to_numeric, errors='coerce')
model_small_df['wind_deg'] = model_small_df['wind_deg'].apply(pd.to_numeric, errors='coerce')
model_small_df['clouds_all'] = model_small_df['clouds_all'].apply(pd.to_numeric, errors='coerce')
model_small_df['weather_id'] = model_small_df['weather_id'].apply(pd.to_numeric, errors='coerce')


print(model_small_df.dtypes)
model_small_df
# Out:
# C:\Users\stefa\Anaconda3\envs\pythondata\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\stefa\Anaconda3\envs\pythondata\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\stefa\Anaconda3\envs\pythondata\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
model_small_df = model_small_df.fillna(0)
model_small_df.head()
# Out:
#    TimeOccurred  AreaID  ReportingDistrict  CrimeCode  VictimAge  PremiseCode  \
# 0          1930       2                201        510       16.0          101
# 1          1915       1                153        440       48.0          502
# 2          1930       2                237        330       29.0          101
# 3          1900       2                241        420       16.0          101
# 7          1930       6                642        420       16.0          101
#
#    WeaponUsedCode  Location  hour    temp  temp_min  temp_max  pressure  \
# 0             0.0       0.0    19  300.09    295.15    304.15      1013
# 1             0.0       0.0    19  300.09    295.15    304.15      1013
# 2             0.0       0.0    19  300.09    295.15    304.15      1013
# 3             0.0       0.0    19  300.09    295.15    304.15      1013
# 7             0.0       0.0    19  300.09    295.15    304.15      1013
#
#    humidity  wind_speed  wind_deg  clouds_all  weather_id
# ...

# %%
model_small_df.reset_index()
# Out:
#          index  TimeOccurred  AreaID  ReportingDistrict  CrimeCode  VictimAge  \
# 0            0          1930       2                201        510       16.0
# 1            1          1915       1                153        440       48.0
# 2            2          1930       2                237        330       29.0
# 3            3          1900       2                241        420       16.0
# 4            7          1930       6                642        420       16.0
# 5            8          1925       7                713        740       29.0
# 6            9          1920       7                785        740       61.0
# 7           10          1900       8                836        310       64.0
# 8           11          1900       8                851        740       25.0
# 9           12          1900       9                932        440       35.0
# 10          13          1930       9                971        440       16.0
# ...

# %%
# Assign X (data) and y (target) to put into model
X = model_small_df.drop("CrimeCode", axis=1)
y = model_small_df["CrimeCode"]
print(X.shape, y.shape)
# Out:
# (131464, 17) (131464,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.4349581127406235
# Testing Data Score: 0.4332136554494006

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [510 330 440 624 624 440 310 624 330 624]
# First 10 Actual labels: [310, 330, 310, 210, 624, 440, 310, 230, 330, 624]
